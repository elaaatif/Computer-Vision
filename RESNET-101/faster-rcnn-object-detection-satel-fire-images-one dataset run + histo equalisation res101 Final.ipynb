# %% [markdown]
# <div style="background-color:#4c1a6f; padding:20px; text-align:center;">
#     <h1 style="color:white;">FASTER RCNN MODEL FOR FIRE DETECTIONN</h1>
#        <h5 style="color:white;">USING SATELITE IMAGES FOR OBEJCT DETECTION - A COMPUTER VISION PROJECT</hdiv>

# %% [markdown]
# <div style="background-color:#008093; padding:10px; text-align:center;">
#     <h4 style="color:white;">PIP INSTALLS </h4>
#        <h5 style="color:white">">roboflow - for loading the datasets </h5>
# </div>

# %%
# !pip install roboflow torch torchvision matplotlib numpy pycocotools
# Out:
# Collecting roboflow
#   Downloading roboflow-1.1.54-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.5.1+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (0.20.1+cu121)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.26.4)
# Requirement already satisfied: pycocotools in /usr/local/lib/python3.10/dist-packages (2.0.8)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from roboflow) (2025.1.31)
# Collecting idna==3.7 (from roboflow)
#   Downloading idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: cycler in /usr/local/lib/python3.10/dist-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.4.7)
# Requirement already satisfied: opencv-python-headless==4.10.0.84 in /usr/local/lib/python3.10/dist-packages (from roboflow) (4.10.0.84)
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from roboflow) (11.0.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.9.0.post0)
# Collecting python-dotenv (from roboflow)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.32.3)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.17.0)
# Requirement already satisfied: urllib3>=1.26.6 in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.3.0)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.10/dist-packages (from roboflow) (4.67.1)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from roboflow) (6.0.2)
# Requirement already satisfied: requests-toolbelt in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.0.0)
# Collecting filetype (from roboflow)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2024.9.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.10/dist-packages (from numpy) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.10/dist-packages (from numpy) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.10/dist-packages (from numpy) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.10/dist-packages (from numpy) (2025.0.1)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.10/dist-packages (from numpy) (2022.0.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.10/dist-packages (from numpy) (2.4.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: intel-openmp>=2024 in /usr/local/lib/python3.10/dist-packages (from mkl->numpy) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.10/dist-packages (from mkl->numpy) (2022.0.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.10/dist-packages (from tbb==2022.*->mkl->numpy) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.10/dist-packages (from mkl_umath->numpy) (2024.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->roboflow) (3.4.1)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.10/dist-packages (from intel-openmp>=2024->mkl->numpy) (2024.2.0)
# Downloading roboflow-1.1.54-py3-none-any.whl (83 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.1/83.1 kB 3.3 MB/s eta 0:00:00
# Downloading idna-3.7-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/66.8 kB ? eta -:--:--
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 4.2 MB/s eta 0:00:00
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Installing collected packages: filetype, python-dotenv, idna, roboflow
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-decision-forests 1.10.0 requires tensorflow==2.17.0, but you have tensorflow 2.17.1 which is incompatible.
# Successfully installed filetype-1.2.0 idna-3.7 python-dotenv-1.0.1 roboflow-1.1.54

# %% [markdown]
# > https://universe.roboflow.com/testes-jnrhu/wildfire-n12rk/dataset/1#

# %% [markdown]
# Preprocessing
# Auto-Orient: Applied
# Resize: Stretch to 640x640
# Augmentations
# No augmentations were applied.

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="7IyVahMNGQIrl0do1Zz8")
project = rf.workspace("testes-jnrhu").project("wildfire-n12rk")
version = project.version(1)
dataset = version.download("yolov8-obb")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in wildfire-1 to yolov8-obb::   0%|          | 0/27353 [00:00<?, ?it/s]
# Downloading Dataset Version Zip in wildfire-1 to yolov8-obb::  26%|██▌       | 6976/27353 [00:00<00:00, 69748.43it/s]
# Downloading Dataset Version Zip in wildfire-1 to yolov8-obb::  54%|█████▎    | 14702/27353 [00:00<00:00, 74163.93it/s]
# Downloading Dataset Version Zip in wildfire-1 to yolov8-obb::  82%|████████▏ | 22380/27353 [00:00<00:00, 75356.31it/s]
# Downloading Dataset Version Zip in wildfire-1 to yolov8-obb:: 100%|██████████| 27353/27353 [00:00<00:00, 75087.11it/s]
# Extracting Dataset Version Zip to wildfire-1 in yolov8-obb::   0%|          | 0/1012 [00:00<?, ?it/s]
# Extracting Dataset Version Zip to wildfire-1 in yolov8-obb::  67%|██████▋   | 679/1012 [00:00<00:00, 6789.15it/s]
# Extracting Dataset Version Zip to wildfire-1 in yolov8-obb:: 100%|██████████| 1012/1012 [00:00<00:00, 7305.30it/s]

# %% [markdown]
# > https://universe.roboflow.com/bairock/wildfire-satellite/dataset/2#

# %% [markdown]
# Preprocessing
# Auto-Orient: Applied
# Resize: Stretch to 416x416
# Augmentations
# Outputs per training example: 3
# Flip: Horizontal, Vertical

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="7IyVahMNGQIrl0do1Zz8")
project = rf.workspace("bairock").project("wildfire-satellite")
version = project.version(2)
dataset = version.download("yolov8-obb")
                #THIS WHAT I USED
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in Wildfire-Satellite-2 to yolov8-obb::   0%|          | 0/239413 [00:00<?, ?it/s]
# Downloading Dataset Version Zip in Wildfire-Satellite-2 to yolov8-obb::   3%|▎         | 7797/239413 [00:00<00:02, 77953.53it/s]
# Downloading Dataset Version Zip in Wildfire-Satellite-2 to yolov8-obb::   7%|▋         | 16207/239413 [00:00<00:02, 81558.20it/s]
# Downloading Dataset Version Zip in Wildfire-Satellite-2 to yolov8-obb::  10%|█         | 24653/239413 [00:00<00:02, 82878.41it/s]
# Downloading Dataset Version Zip in Wildfire-Satellite-2 to yolov8-obb::  14%|█▍        | 33170/239413 [00:00<00:02, 83781.07it/s]
# Downloading Dataset Version Zip in Wildfire-Satellite-2 to yolov8-obb::  17%|█▋        | 41611/239413 [00:00<00:02, 84005.64it/s]
# Downloading Dataset Version Zip in Wildfire-Satellite-2 to yolov8-obb::  21%|██        | 50097/239413 [00:00<00:02, 84293.53it/s]
# Downloading Dataset Version Zip in Wildfire-Satellite-2 to yolov8-obb::  24%|██▍       | 58531/239413 [00:00<00:02, 84307.43it/s]
# Downloading Dataset Version Zip in Wildfire-Satellite-2 to yolov8-obb::  28%|██▊       | 67050/239413 [00:00<00:02, 84585.91it/s]
# Downloading Dataset Version Zip in Wildfire-Satellite-2 to yolov8-obb::  32%|███▏      | 75509/239413 [00:00<00:01, 84373.41it/s]
# Downloading Dataset Version Zip in Wildfire-Satellite-2 to yolov8-obb::  35%|███▌      | 83947/239413 [00:01<00:01, 84060.24it/s]
# Downloading Dataset Version Zip in Wildfire-Satellite-2 to yolov8-obb::  39%|███▊      | 92354/239413 [00:01<00:01, 83169.65it/s]
# Downloading Dataset Version Zip in Wildfire-Satellite-2 to yolov8-obb::  42%|████▏     | 100673/239413 [00:01<00:01, 81122.39it/s]
# Downloading Dataset Version Zip in Wildfire-Satellite-2 to yolov8-obb::  45%|████▌     | 108796/239413 [00:01<00:01, 77696.00it/s]
# Downloading Dataset Version Zip in Wildfire-Satellite-2 to yolov8-obb::  49%|████▉     | 117268/239413 [00:01<00:01, 79717.07it/s]
# Downloading Dataset Version Zip in Wildfire-Satellite-2 to yolov8-obb::  53%|█████▎    | 125740/239413 [00:01<00:01, 81173.28it/s]
# Downloading Dataset Version Zip in Wildfire-Satellite-2 to yolov8-obb::
/s]
# Downloading Dataset Version Zip in fire_forest_new-8 to yolov8-obb::  63%|██████▎   | 50152/80043 [00:00<00:00, 75662.64it/s]
# Downloading Dataset Version Zip in fire_forest_new-8 to yolov8-obb::  72%|███████▏  | 57878/80043 [00:00<00:00, 76169.55it/s]
# Downloading Dataset Version Zip in fire_forest_new-8 to yolov8-obb::  82%|████████▏ | 65608/80043 [00:00<00:00, 76521.90it/s]
# Downloading Dataset Version Zip in fire_forest_new-8 to yolov8-obb::  92%|█████████▏| 73524/80043 [00:01<00:00, 77327.30it/s]
# Downloading Dataset Version Zip in fire_forest_new-8 to yolov8-obb:: 100%|██████████| 80043/80043 [00:01<00:00, 74037.13it/s]
# Extracting Dataset Version Zip to fire_forest_new-8 in yolov8-obb::   0%|          | 0/1045 [00:00<?, ?it/s]
# Extracting Dataset Version Zip to fire_forest_new-8 in yolov8-obb::  24%|██▎       | 247/1045 [00:00<00:00, 2462.28it/s]
# Extracting Dataset Version Zip to fire_forest_new-8 in yolov8-obb::  80%|████████  | 836/1045 [00:00<00:00, 4463.48it/s]
# Extracting Dataset Version Zip to fire_forest_new-8 in yolov8-obb:: 100%|██████████| 1045/1045 [00:00<00:00, 4159.62it/s]

# %% [markdown]
# > https://universe.roboflow.com/fireforestgen/fire_forest_gen/dataset/8

# %% [markdown]
# Preprocessing
# Resize: Stretch to 800x800
# Augmentations
# No augmentations were applied.

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="7IyVahMNGQIrl0do1Zz8")
project = rf.workspace("fireforestgen").project("fire_forest_gen")
version = project.version(8)
dataset = version.download("yolov8-obb")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in fire_forest_gen-8 to yolov8-obb::   0%|          | 0/39471 [00:00<?, ?it/s]
# Downloading Dataset Version Zip in fire_forest_gen-8 to yolov8-obb::  19%|█▉        | 7532/39471 [00:00<00:00, 75315.58it/s]
# Downloading Dataset Version Zip in fire_forest_gen-8 to yolov8-obb::  38%|███▊      | 15064/39471 [00:00<00:00, 72248.14it/s]
# Downloading Dataset Version Zip in fire_forest_gen-8 to yolov8-obb::  59%|█████▉    | 23224/39471 [00:00<00:00, 76415.74it/s]
# Downloading Dataset Version Zip in fire_forest_gen-8 to yolov8-obb::  80%|████████  | 31685/39471 [00:00<00:00, 79602.01it/s]
# Downloading Dataset Version Zip in fire_forest_gen-8 to yolov8-obb:: 100%|██████████| 39471/39471 [00:00<00:00, 78511.25it/s]
# Extracting Dataset Version Zip to fire_forest_gen-8 in yolov8-obb::   0%|          | 0/985 [00:00<?, ?it/s]
# Extracting Dataset Version Zip to fire_forest_gen-8 in yolov8-obb::  45%|████▍     | 443/985 [00:00<00:00, 4428.52it/s]
# Extracting Dataset Version Zip to fire_forest_gen-8 in yolov8-obb:: 100%|██████████| 985/985 [00:00<00:00, 6201.63it/s]

# %% [markdown]
# > https://universe.roboflow.com/12345-su5ee/-c956b/dataset/1#

# %% [markdown]
# Preprocessing
# Auto-Orient: Applied
# Resize: Stretch to 640x640
# Augmentations
# No augmentations were applied.

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="7IyVahMNGQIrl0do1Zz8")
project = rf.workspace("12345-su5ee").project("-c956b")
version = project.version(1)
dataset = version.download("yolov8-obb")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in Хакатон-Пожары-1 to yolov8-obb::   0%|          | 0/7923 [00:00<?, ?it/s]
# Downloading Dataset Version Zip in Хакатон-Пожары-1 to yolov8-obb::  96%|█████████▋| 7639/7923 [00:00<00:00, 76385.34it/s]
# Downloading Dataset Version Zip in Хакатон-Пожары-1 to yolov8-obb:: 100%|██████████| 7923/7923 [00:00<00:00, 74971.28it/s]
# Extracting Dataset Version Zip to Хакатон-Пожары-1 in yolov8-obb::   0%|          | 0/240 [00:00<?, ?it/s]
# Extracting Dataset Version Zip to Хакатон-Пожары-1 in yolov8-obb:: 100%|██████████| 240/240 [00:00<00:00, 6631.22it/s]

# %% [markdown]
# > https://universe.roboflow.com/davidturati/640x640-xdhu3/dataset/24#

# %% [markdown]
# - Preprocessing
# Auto-Orient: Applied
# Resize: Stretch to 640x6*
# 4- 0
# Augmentations
# Outputs per training example: 3
# Flip: Horizontal, Vertical
# 90° Rotate: Clockwise, Counter-Clockwise, Upside Down
# Crop: 0% Minimum Zoom, 20% Maximum Zoom
# Grayscale: Apply to 15% of images
# Hue: Between -15° and +15°
# Saturation: Between -25% and +25%
# Brightness: Between -15% and +15%
# Exposure: Between -10% and +10%
# Noise: Up to 0.1% of pixels
# Cutout: 3 boxes with0% size each
# *

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="7IyVahMNGQIrl0do1Zz8")
project = rf.workspace("davidturati").project("640x640-xdhu3")
version = project.version(24)
dataset = version.download("yolov8-obb")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in 640x640-24 to yolov8-obb::   0%|          | 0/167436 [00:00<?, ?it/s]
# Downloading Dataset Version Zip in 640x640-24 to yolov8-obb::   5%|▍         | 7902/167436 [00:00<00:02, 79013.48it/s]
# Downloading Dataset Version Zip in 640x640-24 to yolov8-obb::  10%|▉         | 16271/167436 [00:00<00:01, 81763.07it/s]
# Downloading Dataset Version Zip in 640x640-24 to yolov8-obb::  15%|█▍        | 24527/167436 [00:00<00:01, 82122.70it/s]
# Downloading Dataset Version Zip in 640x640-24 to yolov8-obb::  20%|█▉        | 32973/167436 [00:00<00:01, 83042.61it/s]
# Downloading Dataset Version Zip in 640x640-24 to yolov8-obb::  25%|██▍       | 41278/167436 [00:00<00:01, 75125.55it/s]
# Downloading Dataset Version Zip in 640x640-24 to yolov8-obb::  29%|██▉       | 48906/167436 [00:00<00:01, 70813.86it/s]
# Downloading Dataset Version Zip in 640x640-24 to yolov8-obb::  33%|███▎      | 56088/167436 [00:00<00:01, 70027.05it/s]
# Downloading Dataset Version Zip in 640x640-24 to yolov8-obb::  38%|███▊      | 63336/167436 [00:00<00:01, 70748.51it/s]
# Downloading Dataset Version Zip in 640x640-24 to yolov8-obb::  42%|████▏     | 70460/167436 [00:00<00:01, 70023.04it/s]
# Downloading Dataset Version Zip in 640x640-24 to yolov8-obb::  47%|████▋     | 78131/167436 [00:01<00:01, 71997.38it/s]
# Downloading Dataset Version Zip in 640x640-24 to yolov8-obb::  51%|█████     | 85647/167436 [00:01<00:01, 72935.18it/s]
# Downloading Dataset Version Zip in 640x640-24 to yolov8-obb::  56%|█████▌    | 93684/167436 [00:01<00:00, 75147.42it/s]
# Downloading Dataset Version Zip in 640x640-24 to yolov8-obb::  61%|██████    | 101838/167436 [00:01<00:00, 77052.80it/s]
# Downloading Dataset Version Zip in 640x640-24 to yolov8-obb::  66%|██████▌   | 110071/167436 [00:01<00:00, 78627.65it/s]
# Downloading Dataset Version Zip in 640x640-24 to yolov8-obb::  70%|███████   | 117999/167436 [00:01<00:00, 78821.62it/s]
# Downloading Dataset Version Zip in 640x640-24 to yolov8-obb::  75%|███████▌  | 125892/167436 [00:01<00:00, 77580.12it/s]
# Downloading Dataset Version Zip in 640x640-24 to yolov8-obb::  80%|███████▉  | 133661/167436 [00:01<00:00, 73529.29it/s]
# Downloading Dataset Version Zip in 640x640-24 to yolov8-obb::  84%|████████▍ | 141062/167436 [00:01<00:00, 71925.59it/s]
# Downloading Dataset Version Zip in 640x640-24 to yolov8-obb::  89%|████████▉ | 149267/167436 [00:01<00:00, 74812.13it/s]
# Downloading Dataset Version Zip in 640x640-24 to yolov8-obb::  94%|█████████▍| 157549/167436 [00:02<00:00, 77127.93it/s]
# Downloading Dataset Version Zip in 640x640-24 to yolov8-obb::  99%|█████████▉| 165499/167436 [00:02<00:00, 77820.85it/s]
# Downloading Dataset Version Zip in 640x640-24 to yolov8-obb:: 100%|██████████| 167436/167436 [00:02<00:00, 75486.50it/s]
# Extracting Dataset Version Zip to 640x640-24 in yolov8-obb::   0%|          | 0/7138 [00:00<?, ?it/s]
# Extracting Dataset Version Zip to 640x640-24 in yolov8-obb::  10%|▉         | 684/7138 [00:00<00:00, 6836.94it/s]
# Extracting Dataset Version Zip to 640x640-24 in yolov8-obb::  19%|█▉        | 1368/7138 [00:00<00:00, 6289.36it/s]
# Extracting Dataset Version Zip to 640x640-24 in yolov8-obb::  28%|██▊       | 2000/7138 [00:00<00:00, 6159.37it/s]
# Extracting Dataset Version Zip to 640x640-24 in yolov8-obb::  37%|███▋      | 2618/7138 [00:00<00:00, 6090.67it/s]
# Extracting Dataset Version Zip to 640x640-24 in yolov8-obb::  45%|████▌     | 3228/7138 [00:00<00:00, 6089.27it/s]
# Extracting Dataset Version Zip to 640x640-24 in yolov8-obb::  59%|█████▉    | 4205/7138 [00:00<00:00, 7309.76it/s]
# Extracting Dataset Version Zip to 640x640-24 in yolov8-obb::  75%|███████▌  | 5380/7138 [00:00<00:00, 8735.74it/s]
# Extracting Dataset Version Zip to 640x640-24 in yolov8-obb::  91%|█████████ | 6493/7138 [00:00<00:00, 9487.78it/s]
# Extracting Dataset Version Zip to 640x640-24 in yolov8-obb:: 100%|██████████| 7138/7138 [00:00<00:00, 7840.91it/s]

# %% [markdown]
# > https://universe.roboflow.com/pfc-dshky/fire-detection2-wayva/dataset/1

# %% [markdown]
# - Preprocessing
# Auto-Orient: Applied
# Resize: Stretch to 640x6
# 4- 0
# Augmentations
# Outputs per training example: 3
# Flip: Horizontal, Vertical
# 90° Rotate: Clockwise, Counter-Clockwise, Upside Down

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="7IyVahMNGQIrl0do1Zz8")
project = rf.workspace("pfc-dshky").project("fire-detection2-wayva")
version = project.version(1)
dataset = version.download("yolov8-obb")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in fire-detection2-1 to yolov8-obb::   0%|          | 0/79566 [00:00<?, ?it/s]
# Downloading Dataset Version Zip in fire-detection2-1 to yolov8-obb::   9%|▉         | 7323/79566 [00:00<00:00, 73226.58it/s]
# Downloading Dataset Version Zip in fire-detection2-1 to yolov8-obb::  19%|█▉        | 15090/79566 [00:00<00:00, 75838.86it/s]
# Downloading Dataset Version Zip in fire-detection2-1 to yolov8-obb::  29%|██▉       | 23002/79566 [00:00<00:00, 77334.83it/s]
# Downloading Dataset Version Zip in fire-detection2-1 to yolov8-obb::  39%|███▉      | 31107/79566 [00:00<00:00, 78773.35it/s]
# Downloading Dataset Version Zip in fire-detection2-1 to yolov8-obb::  49%|████▉     | 39233/79566 [00:00<00:00, 79666.16it/s]
# Downloading Dataset Version Zip in fire-detection2-1 to yolov8-obb::  59%|█████▉    | 47228/79566 [00:00<00:00, 79760.54it/s]
# Downloading Dataset Version Zip in fire-detection2-1 to yolov8-obb::  70%|██████▉   | 55385/79566 [00:00<00:00, 80345.08it/s]
# Downloading Dataset Version Zip in fire-detection2-1 to yolov8-obb::  80%|███████▉  | 63420/79566 [00:00<00:00, 80295.91it/s]
# Downloading Dataset Version Zip in fire-detection2-1 to yolov8-obb::  90%|████████▉ | 71450/79566 [00:00<00:00, 80278.56it/s]
# Downloading Dataset Version Zip in fire-detection2-1 to yolov8-obb:: 100%|█████████▉| 79478/79566 [00:01<00:00, 80133.06it/s]
# Downloading Dataset Version Zip in fire-detection2-1 to yolov8-obb:: 100%|██████████| 79566/79566 [00:01<00:00, 79266.40it/s]
# Extracting Dataset Version Zip to fire-detection2-1 in yolov8-obb::   0%|          | 0/5788 [00:00<?, ?it/s]
# Extracting Dataset Version Zip to fire-detection2-1 in yolov8-obb::  16%|█▌        | 903/5788 [00:00<00:00, 9029.53it/s]
# Extracting Dataset Version Zip to fire-detection2-1 in yolov8-obb::  31%|███       | 1806/5788 [00:00<00:00, 8179.85it/s]
# Extracting Dataset Version Zip to fire-detection2-1 in yolov8-obb::  45%|████▌     | 2630/5788 [00:00<00:00, 8106.52it/s]
# Extracting Dataset Version Zip to fire-detection2-1 in yolov8-obb::  67%|██████▋   | 3897/5788 [00:00<00:00, 9835.33it/s]
# Extracting Dataset Version Zip to fire-detection2-1 in yolov8-obb::  86%|████████▌ | 4969/5788 [00:00<00:00, 10144.48it/s]
# Extracting Dataset Version Zip to fire-detection2-1 in yolov8-obb:: 100%|██████████| 5788/5788 [00:00<00:00, 9730.85it/s]

# %% [markdown]
# > https://universe.roboflow.com/htw-berlin-xv7eo/dlr/dataset/1

# %% [markdown]
# * Preprocessing
# Auto-Orient: Applied
# Resize: Stretch to 1000x100* 0
# Augmentations
# Outputs per training example: 3
# 90° Rotate: Clockwise, Counter-Clockwise, Upside Down
# Crop: 0% Minimum Zoom, 32% Maximum Zoom
# Hue: Between -25° and +25°
# Saturation: Between -52% and +52%
# Exposure: Between -25% and +25%
# Blur: Up to 1.75px
# Noise: Up to 5% of pixels *

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="7IyVahMNGQIrl0do1Zz8")
project = rf.workspace("htw-berlin-xv7eo").project("dlr")
version = project.version(1)
dataset = version.download("yolov8-obb")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in DLR-1 to yolov8-obb::   0%|          | 0/270176 [00:00<?, ?it/s]
# Downloading Dataset Version Zip in DLR-1 to yolov8-obb::   3%|▎         | 7776/270176 [00:00<00:03, 77755.44it/s]
# Downloading Dataset Version Zip in DLR-1 to yolov8-obb::   6%|▌         | 15552/270176 [00:00<00:03, 75740.50it/s]
# Downloading Dataset Version Zip in DLR-1 to yolov8-obb::   9%|▊         | 23303/270176 [00:00<00:03, 76534.69it/s]
# Downloading Dataset Version Zip in DLR-1 to yolov8-obb::  12%|█▏        | 31146/270176 [00:00<00:03, 77273.49it/s]
# Downloading Dataset Version Zip in DLR-1 to yolov8-obb::  14%|█▍        | 38904/270176 [00:00<00:02, 77378.20it/s]
# Downloading Dataset Version Zip in DLR-1 to yolov8-obb::  17%|█▋        | 47202/270176 [00:00<00:02, 79273.26it/s]
# Downloading Dataset Version Zip in DLR-1 to yolov8-obb::  20%|██        | 55132/270176 [00:00<00:02, 79154.86it/s]
# Downloading Dataset Version Zip in DLR-1 to yolov8-obb::  23%|██▎       | 63049/270176 [00:00<00:02, 78859.83it/s]
# Downloading Dataset Version Zip in DLR-1 to yolov8-obb::  26%|██▋       | 70936/270176 [00:00<00:02, 78624.43it/s]
# Downloading Dataset Version Zip in DLR-1 to yolov8-obb::  29%|██▉       | 78800/270176 [00:01<00:02, 78576.59it/s]
# Downloading Dataset Version Zip in DLR-1 to yolov8-obb::  32%|███▏      | 86734/270176 [00:01<00:02, 78807.87it/s]
# Downloading Dataset Version Zip in DLR-1 to yolov8-obb::  35%|███▌      | 94636/270176 [00:01<00:02, 78871.27it/s]
# Downloading Dataset Version Zip in DLR-1 to yolov8-obb::  38%|███▊      | 102524/270176 [00:01<00:02, 78667.53it/s]
# Downloading Dataset Version Zip in DLR-1 to yolov8-obb::  41%|████      | 110392/270176 [00:01<00:02, 73481.23it/s]
# Downloading Dataset Version Zip in DLR-1 to yolov8-obb::  44%|████▎     | 117808/270176 [00:01<00:02, 72872.96it/s]
# Downloading Dataset Version Zip in DLR-1 to yolov8-obb::  46%|████▋     | 125602/270176 [00:01<00:01, 74332.46it/s]
# Downloading Dataset Version Zip in DLR-1 to yolov8-obb::  49%|████▉     | 133574/270176 [00:01<00:01, 75901.99it/s]
# Downloading Dataset Version Zip in DLR-1 to yolov8-obb::  52%|█████▏    | 141617/270176 [00:01<00:01, 77230.66it/s]
# Downloading Dataset Version Zip in DLR-1 to yolov8-obb::  55%|█████▌    | 149439/270176 [00:01<00:01, 77519.55it/s]
# Downloading Dataset Version Zip in DLR-1 to yolov8-obb::  58%|█████▊    | 157600/270176 [00:02<00:01, 78732.26it/s]
# Downloading Dataset Version Zip in DLR-1 to yolov8-obb::  61%|██████▏   | 165728/270176 [00:02<00:01, 79486.04it/s]
# Downloading Dataset Version Zip in DLR-1 to yolov8-obb::  64%|██████▍   | 173964/270176 [00:02<00:01, 80342.74it/s]
# Downloading Dataset Version Zip in DLR-1 to yolov8-obb::  67%|██████▋   | 182104/270176 [00:02<00:01, 80657.64it/s]
# Downloading Dataset Version Zip in DLR-1 to yolov8-obb::  70%|███████   | 190292/270176 [00:02<00:00, 81021.99it/s]
# Downloading Dataset Version Zip in DLR-1 to yolov8-obb::  73%|███████▎  | 198399/270176 [00:02<00:00, 80616.35it/s]
# Downloading Dataset Version Zip in DLR-1 to yolov8-obb::  76%|███████▋  | 206616/270176 [00:02<00:00, 81077.91it/s]
# Downloading Dataset Version Zip in DLR-1 to yolov8-obb::  79%|███████▉  | 214788/270176 [00:02<00:00, 81269.15it/s]
# Downloading Dataset Version Zip in DLR-1 to yolov8-obb::  83%|████████▎ | 223000/270176 [00:02<00:00, 81518.41it/s]
# Downloading Dataset Version Zip in DLR-1 to yolov8-obb::  86%|████████▌ | 231154/270176 [00:02<00:00, 81320.05it/s]
# Downloading Dataset Version Zip in DLR-1 to yolov8-obb::  89%|████████▊ | 239287/270176 [00:03<00:00, 81308.26it/s]
# Downloading Dataset Version Zip in DLR-1 to yolov8-obb::  92%|█████████▏| 247441/270176 [00:03<00:00, 81374.05it/s]
# Downloading Dataset Version Zip in DLR-1 to yolov8-obb::  95%|█████████▍| 255579/270176 [00:03<00:00, 81365.57it/s]
# Downloading Dataset Version Zip in DLR-1 to yolov8-obb::  98%|█████████▊| 263716/270176 [00:03<00:00, 80348.11it/s]
# Downloading Dataset Version Zip in DLR-1 to yolov8-obb:: 100%|██████████| 270176/270176 [00:03<00:00, 78957.44it/s]
# Extracting Dataset Version Zip to DLR-1 in yolov8-obb::   0%|          | 0/2398 [00:00<?, ?it/s]
# Extracting Dataset Version Zip to DLR-1 in yolov8-obb::  10%|▉         | 231/2398 [00:00<00:00, 2302.15it/s]
# Extracting Dataset Version Zip to DLR-1 in yolov8-obb::  19%|█▉        | 462/2398 [00:00<00:00, 1987.02it/s]
# Extracting Dataset Version Zip to DLR-1 in yolov8-obb::  28%|██▊       | 664/2398 [00:00<00:00, 1869.30it/s]
# Extracting Dataset Version Zip to DLR-1 in yolov8-obb::  36%|███▌      | 853/2398 [00:00<00:00, 1852.55it/s]
# Extracting Dataset Version Zip to DLR-1 in yolov8-obb::  43%|████▎     | 1040/2398 [00:00<00:00, 1809.54it/s]
# Extracting Dataset Version Zip to DLR-1 in yolov8-obb::  65%|██████▌   | 1570/2398 [00:00<00:00, 2921.37it/s]
# Extracting Dataset Version Zip to DLR-1 in yolov8-obb:: 100%|██████████| 2398/2398 [00:00<00:00, 3253.62it/s]

# %% [markdown]
# > https://universe.roboflow.com/di-gao/volcano-nztt3/dataset/19

# %% [markdown]
# - Preprocessing
# Auto-Orient: Applied
# Resize: Stretch to 416x41- 6
# Augmentations
# Outputs per training example: 3
# Flip: Horizontal, Vertical
# 90° Rotate: Clockwise, Counter-Clockwise, Upside Down
# Blur: Up to 1px
# Noise: Up to 5% of pixels

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="7IyVahMNGQIrl0do1Zz8")
project = rf.workspace("di-gao").project("volcano-nztt3")
version = project.version(19)
dataset = version.download("yolov8-obb")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in volcano-19 to yolov8-obb::   0%|          | 0/17054 [00:00<?, ?it/s]
# Downloading Dataset Version Zip in volcano-19 to yolov8-obb::  42%|████▏     | 7099/17054 [00:00<00:00, 70978.05it/s]
# Downloading Dataset Version Zip in volcano-19 to yolov8-obb::  86%|████████▌ | 14694/17054 [00:00<00:00, 73899.04it/s]
# Downloading Dataset Version Zip in volcano-19 to yolov8-obb:: 100%|██████████| 17054/17054 [00:00<00:00, 73557.42it/s]
# Extracting Dataset Version Zip to volcano-19 in yolov8-obb::   0%|          | 0/612 [00:00<?, ?it/s]
# Extracting Dataset Version Zip to volcano-19 in yolov8-obb:: 100%|██████████| 612/612 [00:00<00:00, 7367.02it/s]

# %% [markdown]
# > https://universe.roboflow.com/umbc-s6g8c/wildfire-detection-satellite/dataset/3

# %% [markdown]
# - Preprocessing
# Auto-Orient: Applied
# Resize: Stretch to 640x640
# Tile: 2 rows x 2 colu -m- ns
# Augmentations
# Outputs per training example: 3
# Flip: Horizontal, Vertical
# Rotation: Between -15° and +15°
# Saturation: Between -25% and +25%

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="
/s]
# Extracting Dataset Version Zip to Wildfire-Detection-Satellite-3 in yolov8-obb::  67%|██████▋   | 40858/60972 [00:04<00:01, 13245.67it/s]
# Extracting Dataset Version Zip to Wildfire-Detection-Satellite-3 in yolov8-obb::  69%|██████▉   | 42185/60972 [00:04<00:01, 13191.61it/s]
# Extracting Dataset Version Zip to Wildfire-Detection-Satellite-3 in yolov8-obb::  71%|███████▏  | 43507/60972 [00:04<00:01, 13199.17it/s]
# Extracting Dataset Version Zip to Wildfire-Detection-Satellite-3 in yolov8-obb::  74%|███████▎  | 44828/60972 [00:04<00:01, 13163.87it/s]
# Extracting Dataset Version Zip to Wildfire-Detection-Satellite-3 in yolov8-obb::  76%|███████▌  | 46145/60972 [00:04<00:01, 13078.07it/s]
# Extracting Dataset Version Zip to Wildfire-Detection-Satellite-3 in yolov8-obb::  78%|███████▊  | 47493/60972 [00:04<00:01, 13194.59it/s]
# Extracting Dataset Version Zip to Wildfire-Detection-Satellite-3 in yolov8-obb::  80%|████████  | 48813/60972 [00:04<00:00, 13127.10it/s]
# Extracting Dataset Version Zip to Wildfire-Detection-Satellite-3 in yolov8-obb::  82%|████████▏ | 50127/60972 [00:05<00:01, 10716.44it/s]
# Extracting Dataset Version Zip to Wildfire-Detection-Satellite-3 in yolov8-obb::  84%|████████▍ | 51271/60972 [00:05<00:01, 9374.70it/s]
# Extracting Dataset Version Zip to Wildfire-Detection-Satellite-3 in yolov8-obb::  86%|████████▌ | 52282/60972 [00:05<00:01, 8482.91it/s]
# Extracting Dataset Version Zip to Wildfire-Detection-Satellite-3 in yolov8-obb::  87%|████████▋ | 53189/60972 [00:05<00:00, 8143.95it/s]
# Extracting Dataset Version Zip to Wildfire-Detection-Satellite-3 in yolov8-obb::  89%|████████▊ | 54042/60972 [00:05<00:00, 7832.57it/s]
# Extracting Dataset Version Zip to Wildfire-Detection-Satellite-3 in yolov8-obb::  90%|████████▉ | 54850/60972 [00:05<00:00, 7402.21it/s]
# Extracting Dataset Version Zip to Wildfire-Detection-Satellite-3 in yolov8-obb::  92%|█████████▏| 55999/60972 [00:05<00:00, 8413.84it/s]
# Extracting Dataset Version Zip to Wildfire-Detection-Satellite-3 in yolov8-obb::  94%|█████████▍| 57264/60972 [00:06<00:00, 9519.36it/s]
# Extracting Dataset Version Zip to Wildfire-Detection-Satellite-3 in yolov8-obb::  96%|█████████▌| 58419/60972 [00:06<00:00, 10067.92it/s]
# Extracting Dataset Version Zip to Wildfire-Detection-Satellite-3 in yolov8-obb::  98%|█████████▊| 59622/60972 [00:06<00:00, 10614.68it/s]
# Extracting Dataset Version Zip to Wildfire-Detection-Satellite-3 in yolov8-obb:: 100%|█████████▉| 60840/60972 [00:06<00:00, 11059.84it/s]
# Extracting Dataset Version Zip to Wildfire-Detection-Satellite-3 in yolov8-obb:: 100%|██████████| 60972/60972 [00:06<00:00, 9617.39it/s]

# %%
# import os

# class UniqueLabelsExtractor:
#     def __init__(self, labels_dir):
#         self.labels_dir = labels_dir

#     def get_unique_labels(self):
#         unique_labels = set()

#         label_files = os.listdir(self.labels_dir)
#         for label_file in label_files:
#             label_path = os.path.join(self.labels_dir, label_file)
#             with open(label_path, 'r', encoding='latin1') as f:
#                 for line in f:
#                     parts = line.strip().split()
#                     if not parts or len(parts) < 5:
#                         continue  # Skip empty or invalid lines
#                     label = int(parts[0])  # Adjusting label index
#                     unique_labels.add(label)

#         return sorted(unique_labels)

# # Example usage:
# labels_dir = "/kaggle/working/combined_dataset/train/labels"
# extractor = UniqueLabelsExtractor(labels_dir)
# unique_labels = extractor.get_unique_labels()
# print("Unique Labels:", unique_labels)

# %%
import os

class UniqueLabelsExtractor:
    def __init__(self, labels_dir):
        self.labels_dir = labels_dir

    def get_unique_labels(self):
        unique_labels = set()
        
        if not os.path.exists(self.labels_dir):
            return unique_labels  # Return empty set if path doesn't exist

        label_files = os.listdir(self.labels_dir)
        for label_file in label_files:
            label_path = os.path.join(self.labels_dir, label_file)
            with open(label_path, 'r', encoding='latin1') as f:
                for line in f:
                    parts = line.strip().split()
                    if not parts or len(parts) < 5:
                        continue  # Skip empty or invalid lines
                    label = int(parts[0])  # Adjusting label index
                    unique_labels.add(label)
        
        return unique_labels

# Define base path and dataset folders
base_path = "/kaggle/working"
# folders = [
#     "640x640-24", "DLR-1", "Wildfire-2", "Wildfire-Detection-Satellite-3",
#     "Wildfire-Satellite-2", "fire-detection2-1", "fire_forest_gen-8",
#     "fire_forest_new-8", "volcano-19", "wildfire-1", "Хакатон-Пожары-1","combined_dataset"
# ]

folders = [
   "Wildfire-Satellite-2" 
            ]

# Iterate over each dataset folder and extract unique labels
for folder in folders:
    labels_dir = os.path.join(base_path, folder, "train", "labels")
    extractor = UniqueLabelsExtractor(labels_dir)
    unique_labels = extractor.get_unique_labels()
    print(f"Dataset: {folder}, Unique Labels Count: {len(unique_labels)}")
# Out:
# Dataset: Wildfire-Satellite-2, Unique Labels Count: 1

# %% [markdown]
# <div style="background-color:#008093; padding:10px; text-align:center;">
#        <h5 style="color:white;">MERGING THE DATASETS</h5>
#     <h5 style="color:white;">TRAIN - TEST - VALID</h5>
# </div>

# %%
import os
import json
import shutil

# base_path ='/kaggle/working'
# folders = [
#     "640x640-24", "DLR-1", "Wildfire-2",
#     "Wildfire-Satellite-2", "fire-detection2-1", "fire_forest_gen-8",
#     "fire_forest_new-8", "wildfire-1", "Хакатон-Пожары-1"
# ]

# Check the folder structure of each dataset
for folder in folders:
    dataset_path = os.path.join(base_path, folder)
    print(f"Contents of {folder}:")
    print(os.listdir(dataset_path))
    print("-" * 50)
# Out:
# Contents of Wildfire-Satellite-2:
# ['valid', 'README.roboflow.txt', 'data.yaml', 'train', 'README.dataset.txt']
# --------------------------------------------------

# %%
# Define combined dataset paths
combined_path = '/kaggle/working/combined_dataset'

def create_combined_folders(base):
    paths = {}
    for split in ['train', 'valid', 'test']:
        images_path = os.path.join(base, split, 'images')
        labels_path = os.path.join(base, split, 'labels')
        os.makedirs(images_path, exist_ok=True)
        os.makedirs(labels_path, exist_ok=True)
        paths[split] = {'images': images_path, 'labels': labels_path}
    return paths
combined_paths = create_combined_folders(combined_path)

# %%
# Function to merge image or label files
def merge_files(src_folder, dest_folder, folder_name):
    if os.path.exists(src_folder):  # Check if the source folder exists
        for filename in os.listdir(src_folder):
            src_file = os.path.join(src_folder, filename)
            new_filename = f"{folder_name}_{filename}"
            dest_file = os.path.join(dest_folder, new_filename)

            # Avoid overwriting by renaming duplicates
            while os.path.exists(dest_file):
                base, ext = os.path.splitext(new_filename)
                new_filename = f"{base}_copy{ext}"
                dest_file = os.path.join(dest_folder, new_filename)

            shutil.move(src_file, dest_file)

# Iterate through each dataset and move files
for folder in folders:
    dataset_path = os.path.join(base_path, folder)

    for split in ['train', 'valid', 'test']:
        split_images = os.path.join(dataset_path, split, 'images')
        split_labels = os.path.join(dataset_path, split, 'labels')

        merge_files(split_images, combined_paths[split]['images'], folder)
        merge_files(split_labels, combined_paths[split]['labels'], folder)

print("Datasets merged successfully with separate folders for images and labels in each split!")
# Out:
# Datasets merged successfully with separate folders for images and labels in each split!

# %%
# Verify the Combined Dataset
for folder in ['train', 'valid', 'test']:
    folder_path = os.path.join(combined_path, folder)
    images_path = os.path.join(folder_path, 'images')
    labels_path = os.path.join(folder_path, 'labels')
    
    print(f"\n{folder.capitalize()} Folder:")
    
    if os.path.exists(images_path):
        num_images = len(os.listdir(images_path))
        print(f"  - Images folder contains {num_images} files.")
    else:
        print("  - Images folder is missing.")
    
    if os.path.exists(labels_path):
        num_labels = len(os.listdir(labels_path))
        print(f"  - Labels folder contains {num_labels} files.")
    else:
        print("  - Labels folder is missing.")
# Out:
# Train Folder:
#   - Images folder contains 8828 files.
#   - Labels folder contains 8828 files.
#
# Valid Folder:
#   - Images folder contains 200 files.
#   - Labels folder contains 200 files.
#
# Test Folder:
#   - Images folder contains 0 files.
#   - Labels folder contains 0 files.

# %%
import os
import random
import cv2
import matplotlib.pyplot as plt

# Define dataset path
dataset_path = "combined_dataset"
sets = ["train", "valid", "test"]

def visualize_random_image(set_name):
    image_dir = os.path.join(dataset_path, set_name, "images")
    label_dir = os.path.join(dataset_path, set_name, "labels")

    # Get all image files
    image_files = [f for f in os.listdir(image_dir) if f.endswith(('.jpg', '.png', '.jpeg'))]

    if not image_files:
        print(f"No images found in {image_dir}")
        return

    # Select a random image
    random_image_name = random.choice(image_files)
    image_path = os.path.join(image_dir, random_image_name)

    # Load the image
    image = cv2.imread(image_path)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # Convert for Matplotlib

    # Display image without bounding box
    plt.figure(figsize=(10, 5))
    plt.subplot(1, 2, 1)
    plt.imshow(image)
    plt.axis("off")
    plt.title(f"{set_name.capitalize()} Image (No BBox)")

    # Load corresponding annotation
    label_path = os.path.join(label_dir, random_image_name.replace(".jpg", ".txt").replace(".png", ".txt"))

    if os.path.exists(label_path):
        with open(label_path, "r") as f:
            annotations = f.readlines()
        
        h, w, _ = image.shape  # Image dimensions

        for annotation in annotations:
            parts = annotation.strip().split()
            print("Annotation parts:", parts)  # Debugging print

            if len(parts) < 5:
                print(f"Skipping invalid annotation in {label_path}: {annotation}")
                continue

            class_id = int(parts[0])  # Assuming YOLO format
            x_center, y_center, box_w, box_h = map(float, parts[1:5])  # Ensure only 4 values

            # Convert to pixel values
            x1 = int((x_center - box_w / 2) * w)
            y1 = int((y_center - box_h / 2) * h)
            x2 = int((x_center + box_w / 2) * w)
            y2 = int((y_center + box_h / 2) * h)

            # Draw bounding box
            cv2.rectangle(image, (x1, y1), (x2, y2), (255, 0, 0), 2)  # Blue box

    # Display image with bounding box
    plt.subplot(1, 2, 2)
    plt.imshow(image)
    plt.axis("off")
    plt.title(f"{set_name.capitalize()} Image (With BBox)")

    plt.show()

# Run for train, valid, and test
for set_name in sets:
    visualize_random_image(set_name)
# Out:
# Annotation parts: ['0', '0.6009615384615385', '0.5000000000000001', '0.15865384615384623', '0.5', '0.15865384615384626', '0.8870192307692307', '0.6009615384615385', '0.8870192307692307']
# Annotation parts: ['0', '0.875', '9.641149680787457e-17', '0.6995192307692307', '8.566639869035572e-17', '0.6995192307692307', '0.26923076923076933', '0.875', '0.2692307692307694']
# No images found in combined_dataset/test/images

# %% [markdown]
# <div style="background-color:#008093; padding:10px; text-align:center;">
#        <h5 style="color:white;">PREPING THE MODEL</h5>
# </div>

# %%
import torch
import torchvision
from torchvision.models.detection import FasterRCNN
from torchvision.models.detection.rpn import AnchorGenerator
from torchvision.transforms import functional as F
from torch.utils.data import DataLoader, Dataset
from PIL import Image
import os
import torchvision.transforms as transforms
from torch.utils.data import Dataset

# %%
class CustomDataset(Dataset):
    def __init__(self, images_dir, labels_dir, transforms=None, max_samples=None):
        self.images_dir = images_dir
        self.labels_dir = labels_dir
        self.transforms = transforms

        # Get sorted file lists
        self.image_files = sorted([f for f in os.listdir(images_dir) if f.endswith(('.jpg', '.jpeg', '.png'))])
        self.label_files = sorted([f for f in os.listdir(labels_dir) if f.endswith('.txt')])
        
        # Verify matching files
        assert len(self.image_files) == len(self.label_files), "Mismatch between number of images and labels"

        # Apply max_samples limit
        if max_samples is not None:
            self.image_files = self.image_files[:max_samples]
            self.label_files = self.label_files[:max_samples]

    # Keep the rest of the class unchanged
    def __len__(self):
        return len(self.image_files)

    def __getitem__(self, idx):
        # Load image
        img_path = os.path.join(self.images_dir, self.image_files[idx])
        img = Image.open(img_path).convert("RGB")
        img_width, img_height = img.size
    
        # Load labels
        label_path = os.path.join(self.labels_dir, self.label_files[idx])
        boxes = []
        labels = []
        
        try:
            with open(label_path, 'r') as f:
                for line in f:
                    parts = line.strip().split()
                    if len(parts) == 9:  # class + 8 coordinates
                        label = int(parts[0]) +1
                        x_left_down, y_left_down, x_right_down, y_right_down, \
                        x_left_up, y_left_up, x_right_up, y_right_up = map(float, parts[1:9])
                        
                        # Convert normalized coordinates to absolute coordinates
                        points = [
                            [x_left_down * img_width, y_left_down * img_height],
                            [x_right_down * img_width, y_right_down * img_height],
                            [x_left_up * img_width, y_left_up * img_height],
                            [x_right_up * img_width, y_right_up * img_height]
                        ]
                        
                        # Calculate axis-aligned bounding box
                        x_coords = [p[0] for p in points]
                        y_coords = [p[1] for p in points]
                        
                        x_min = min(x_coords)
                        y_min = min(y_coords)
                        x_max = max(x_coords)
                        y_max = max(y_coords)
                        
                        # Ensure coordinates are within image bounds
                        x_min = max(0, min(x_min, img_width))
                        y_min = max(0, min(y_min, img_height))
                        x_max = max(0, min(x_max, img_width))
                        y_max = max(0, min(y_max, img_height))
                        
                        # Only add if box has valid dimensions
                        if x_max > x_min and y_max > y_min:
                            boxes.append([x_min, y_min, x_max, y_max])
                            labels.append(label)
                            
        except Exception as e:
            print(f"Error reading label file {label_path}: {e}")
            return None
    
        # Convert to tensors
        if len(boxes) == 0:
            boxes = torch.zeros((0, 4), dtype=torch.float32)
            labels = torch.zeros(0, dtype=torch.int64)
        else:
            boxes = torch.as_tensor(boxes, dtype=torch.float32)
            labels = torch.as_tensor(labels, dtype=torch.int64)
    
        target = {
            'boxes': boxes,
            'labels': labels,
        }
    
        if self.transforms is not None:
            img = self.transforms(img)
    
        return img, target

# %%
# Define dataset path
dataset_path = "/kaggle/working/combined_dataset"
sets = ["train", "valid", "test"]

def apply_histogram_equalization(image):
    """Apply histogram equalization to improve contrast."""
    img_yuv = cv2.cvtColor(image, cv2.COLOR_RGB2YUV)  # Convert to YUV
    img_yuv[:, :, 0] = cv2.equalizeHist(img_yuv[:, :, 0])  # Equalize Y channel
    return cv2.cvtColor(img_yuv, cv2.COLOR_YUV2RGB)  # Convert back to RGB

def visualize_random_image(set_name):
    image_dir = os.path.join(dataset_path, set_name, "images")
    label_dir = os.path.join(dataset_path, set_name, "labels")
    
    # Get all image files
    image_files = [f for f in os.listdir(image_dir) if f.endswith(('.jpg', '.png', '.jpeg'))]
    
    if not image_files:
        print(f"No images found in {image_dir}")
        return
    
    # Select a random image
    random_image_name = random.choice(image_files)
    image_path = os.path.join(image_dir, random_image_name)
    
    # Load the image
    image = cv2.imread(image_path)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # Convert to RGB
    
    # Apply histogram equalization
    equalized_image = apply_histogram_equalization(image.copy())
    
    # Load corresponding annotation
    label_path = os.path.join(label_dir, random_image_name.replace(".jpg", ".txt").replace(".png", ".txt"))
    
    if os.path.exists(label_path):
        with open(label_path, "r") as f:
            annotations = f.readlines()
        
        h, w, _ = image.shape  # Image dimensions
        
        for annotation in annotations:
            parts = annotation.strip().split()
            if len(parts) < 5:
                continue
            
            class_id = int(parts[0])  # YOLO format
            x_center, y_center, box_w, box_h = map(float, parts[1:5])
            
            # Convert to pixel values
            x1 = int((x_center - box_w / 2) * w)
            y1 = int((y_center - box_h / 2) * h)
            x2 = int((x_center + box_w / 2) * w)
            y2 = int((y_center + box_h / 2) * h)
            
            # Draw bounding boxes on both images
            cv2.rectangle(image, (x1, y1), (x2, y2), (255, 0, 0), 2)  # Original Image
            cv2.rectangle(equalized_image, (x1, y1), (x2, y2), (255, 0, 0), 2)  # Equalized Image
    
    # Display original and equalized image
    plt.figure(figsize=(12, 6))
    plt.subplot(1, 2, 1)
    plt.imshow(image)
    plt.axis("off")
    plt.title("Before Histogram Equalization")
    
    plt.subplot(1, 2, 2)
    plt.imshow(equalized_image)
    plt.axis("off")
    plt.title("After Histogram Equalization")
    
    plt.show()

# Run for train, valid, and test
for set_name in sets:
    visualize_random_image(set_name)
# Out:
# No images found in /kaggle/working/combined_dataset/test/images

# %%
# Define transforms
# def get_transform(train):
#     transform_list = [
#         transforms.Resize((224, 224)),
#         transforms.ToTensor(),  # Convert image to tensor (0-1 range)
#         transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])  # Standard normalization
#     ]
    
#     if train:
#         transform_list.insert(0, transforms.RandomHorizontalFlip(p=0.5))  # Data augmentation for training

#     return transforms.Compose(transform_list)
import torchvision.transforms as transforms

def get_transform(train):
    return transforms.Compose([
        transforms.ToTensor(),  # Convert image to tensor (C, H, W) format
        transforms.Lambda(lambda x: x * 255)  # Scale pixel values to 0-255
    ])



# Create the dataset with 5,000 samples
train_dataset = CustomDataset(
    images_dir='/kaggle/working/combined_dataset/train/images',
    labels_dir='/kaggle/working/combined_dataset/train/labels',
    transforms=get_transform(train=False),
    #max_samples=5000  # <-- Add this line
)

valid_dataset = CustomDataset(
 images_dir='/kaggle/working/combined_dataset/valid/images',
 labels_dir='/kaggle/working/combined_dataset/valid/labels',
 transforms=get_transform(train=False),
  #max_samples=200  # <-- Add this line
)

train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True, collate_fn=lambda x: tuple(zip(*x) ))
valid_loader = DataLoader(valid_dataset, batch_size=16, shuffle=False, collate_fn=lambda x: tuple(zip(*x)))

# %% [markdown]
# # resnet101

# %%
# Load a pre-trained model and modify it for the custom dataset
num_classes = 2  # Update this if you have more classes, 1 for background + N classes
backbone = torchvision.models.resnet101(pretrained=True)
backbone = torch.nn.Sequential(*(list(backbone.children())[:-2]))

# Freeze backbone layers (ADD THIS HERE)
for param in backbone.parameters():
    param.requires_grad = False  # Freezes the backbone

backbone.out_channels = 2048

anchor_generator = AnchorGenerator(
    sizes=((32, 64, 128, 256, 512),),
    aspect_ratios=((0.5, 1.0, 2.0),)
)

roi_pooler = torchvision.ops.MultiScaleRoIAlign(
    featmap_names=['0'], output_size=7, sampling_ratio=2
)

model = FasterRCNN(
    backbone,
    num_classes=num_classes,
    rpn_anchor_generator=anchor_generator,
    box_roi_pool=roi_pooler
)
# Out:
# The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
# Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet101_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet101_Weights.DEFAULT` to get the most up-to-date weights.
# Downloading: "https://download.pytorch.org/models/resnet101-63fe2227.pth" to /root/.cache/torch/hub/checkpoints/resnet101-63fe2227.pth
#   0%|          | 0.00/171M [00:00<?, ?B/s]
#   5%|▍         | 7.75M/171M [00:00<00:02, 81.3MB/s]
#  17%|█▋        | 28.4M/171M [00:00<00:00, 160MB/s]
#  29%|██▊       | 49.0M/171M [00:00<00:00, 186MB/s]
#  42%|████▏     | 72.2M/171M [00:00<00:00, 208MB/s]
#  54%|█████▍    | 92.8M/171M [00:00<00:00, 211MB/s]
#  68%|██████▊   | 116M/171M [00:00<00:00, 220MB/s]
#  80%|████████  | 137M/171M [00:00<00:00, 219MB/s]
#  94%|█████████▎| 160M/171M [00:00<00:00, 226MB/s]
# 100%|██████████| 171M/171M [00:00<00:00, 210MB/s]

# %% [markdown]
# # EFFICIENT NET

# %%
# import torch
# import torchvision
# from torchvision.models.detection import FasterRCNN
# from torchvision.models.detection.rpn import AnchorGenerator
# from torchvision.models import efficientnet_b3

# # # Load EfficientNet-B3 and modify it
# num_classes = 2  # Update this if needed

# #Load the pre-trained EfficientNet model
# efficientnet = efficientnet_b3(weights="IMAGENET1K_V1")
# backbone = efficientnet.features  # Extract feature extractor

# # Freeze backbone layers
# for param in backbone.parameters():
#     param.requires_grad = False

# # Define the number of output channels (last feature map size of EfficientNet-B3)
# backbone.out_channels = 1536  # EfficientNet-B3 last conv layer output channels

# # Define anchor generator
# anchor_generator = AnchorGenerator(
#     sizes=((32, 64, 128, 256, 512),),
#     aspect_ratios=((0.5, 1.0, 2.0),)
# )

# # Define ROI Pooler
# roi_pooler = torchvision.ops.MultiScaleRoIAlign(
#     featmap_names=['0'], output_size=7, sampling_ratio=2
# )

# # Create Faster R-CNN model
# model = FasterRCNN(
#     backbone,
#     num_classes=num_classes,
#     rpn_anchor_generator=anchor_generator,
#     box_roi_pool=roi_pooler
# )

# %% [markdown]
# # FASTER RCNN resnet50

# %%
# Define the optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=0.0001)
# Directory for saving history
history_dir = "/kaggle/working/history"
os.makedirs(history_dir, exist_ok=True)
# History tracking
history = {"epochs": []}
import torch
from torchvision.ops import box_iou
import json
import os
import numpy as np
from sklearn.metrics import precision_recall_fscore_support

def calculate_metrics(pred_boxes, pred_labels, pred_scores, target_boxes, target_labels, iou_threshold=0.5):
    """Calculate object detection metrics for a batch of predictions."""
    batch_iou = 0.0
    batch_precision = 0.0
    batch_recall = 0.0
    batch_f1 = 0.0
    batch_map = 0.0  # mean Average Precision
    
    for pred_box, pred_label, pred_score, target_box, target_label in zip(
        pred_boxes, pred_labels, pred_scores, target_boxes, target_labels):
        
        if len(pred_box) == 0 or len(target_box) == 0:
            continue
            
        # Calculate IoU between predicted and target boxes
        iou_matrix = box_iou(pred_box, target_box)
        
        # Calculate metrics
        matches = iou_matrix > iou_threshold
        true_positives = matches.sum().item()
        false_positives = len(pred_box) - true_positives
        false_negatives = len(target_box) - true_positives
        
        # IoU
        if iou_matrix[matches].numel() > 0:
            batch_iou += iou_matrix[matches].mean().item()
        else:
            # Optionally, you can add 0 or skip this image
            batch_iou += 0.0
        # Precision, Recall, F1
        if true_positives + false_positives > 0:
            precision = true_positives / (true_positives + false_positives)
            batch_precision += precision
        if true_positives + false_negatives > 0:
            recall = true_positives / (true_positives + false_negatives)
            batch_recall += recall
        if precision + recall > 0:
            f1 = 2 * (precision * recall) / (precision + recall)
            batch_f1 += f1
            
        # Calculate mAP
        # Sort predictions by confidence score
        sorted_indices = torch.argsort(pred_score, descending=True)
        pred_box = pred_box[sorted_indices]
        pred_label = pred_label[sorted_indices]
        pred_score = pred_score[sorted_indices]
        
        # Calculate AP for each class
        unique_classes = torch.unique(torch.cat([pred_label, target_label]))
        ap_sum = 0.0
        
        for cls in unique_classes:
            cls_pred_mask = pred_label == cls
            cls_target_mask = target_label == cls
            
            if cls_pred_mask.sum() == 0 or cls_target_mask.sum() == 0:
                continue
                
            cls_iou_matrix = box_iou(pred_box[cls_pred_mask], target_box[cls_target_mask])
            cls_matches = cls_iou_matrix > iou_threshold
            
            # Calculate precision at each threshold
            precisions = []
            for k in range(len(cls_matches)):
                matches_k = cls_matches[:k+1]
                if matches_k.numel() > 0:
                    precisions.append(matches_k.sum().float() / (k + 1))
            
            if precisions:
                ap_sum += torch.tensor(precisions).mean().item()
        
        if len(unique_classes) > 0:
            batch_map += ap_sum / len(unique_classes)
    
    # Calculate batch averages
    num_images = len(pred_boxes)
    return {
        'iou': batch_iou / num_images,
        'precision': batch_precision / num_images,
        'recall': batch_recall / num_images,
        'f1': batch_f1 / num_images,
        'map': batch_map / num_images
    }

def train_one_epoch(model, optimizer, data_loader, device, epoch, history_dir):
    model.train()
    total_loss = 0.0
    total_iou = 0.0
    total_precision = 0.0
    total_recall = 0.0
    total_f1 = 0.0
    total_map = 0.0
    
    for batch_idx, (images, targets) in enumerate(data_loader):
        images = list(img.to(device) for img in images)
        targets = [{k: v.to(device) for k, v in t.items()} for t in targets]
        
        # Forward pass and loss calculation
        loss_dict = model(images, targets)
        losses = sum(loss for loss in loss_dict.values())
        total_loss += losses.item()
        
        # Get predictions by temporarily setting model to eval mode
        model.eval()
        with torch.no_grad():
            predictions = model(images)
        model.train()  # Set back to training mode
        
        # Calculate metrics for the batch
        batch_metrics = calculate_metrics(
            [p['boxes'] for p in predictions],
            [p['labels'] for p in predictions],
            [p['scores'] for p in predictions],
            [t['boxes'] for t in targets],
            [t['labels'] for t in targets]
        )
        
        total_iou += batch_metrics['iou']
        total_precision += batch_metrics['precision']
        total_recall += batch_metrics['recall']
        total_f1 += batch_metrics['f1']
        total_map += batch_metrics['map']
        
        # Backpropagation
        optimizer.zero_grad()
        losses.backward()
        optimizer.step()
        
 
    # Calculate averages
    num_batches = len(data_loader)
    avg_loss = total_loss / num_batches
    avg_iou = total_iou / num_batches
    avg_precision = total_precision / num_batches
    avg_recall = total_recall / num_batches
    avg_f1 = total_f1 / num_batches
    avg_map = total_map / num_batches
    
    # Print metrics
    print(f"\nEpoch {epoch + 1} Summary:")
    print(f"  Loss: {avg_loss:.4f}")
    print(f"  IoU: {avg_iou:.4f}")
    print(f"  Precision: {avg_precision:.4f}")
    print(f"  Recall: {avg_recall:.4f}")
    print(f"  F1-Score: {avg_f1:.4f}")
    print(f"  mAP: {avg_map:.4f}")
    
    # Save history
    history = {
        "epoch": epoch + 1,
        "loss": avg_loss,
        "iou": avg_iou,
        "precision": avg_precision,
        "recall": avg_recall,
        "f1": avg_f1,
        "map": avg_map
    }
    
    # Ensure history directory exists
    os.makedirs(history_dir, exist_ok=True)
    
    # Save to JSON file
    history_file = os.path.join(history_dir, "training_history.json")
    if os.path.exists(history_file):
        with open(history_file, 'r') as f:
            history_data = json.load(f)
            history_data['epochs'].append(history)
    else:
        history_data = {'epochs': [history]}
    
    with open(history_file, 'w') as f:
        json.dump(history_data, f, indent=4)
    
    return avg_loss, history

# %%
# Training loop
num_epochs = 20
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
model.to(device)
history = []
for epoch in range(num_epochs):
    avg_loss, epoch_history = train_one_epoch(model, optimizer, train_loader, device, epoch,history_dir)
    history.append(epoch_history)
print("Training completed!")
# Out:
# Epoch 1 Summary:
#   Loss: 0.3026
#   IoU: 0.3699
#   Precision: 0.0708
#   Recall: 0.8350
#   F1-Score: 0.1187
#   mAP: 0.1051
# Epoch 2 Summary:
#   Loss: 0.2771
#   IoU: 0.4956
#   Precision: 0.1026
#   Recall: 1.1516
#   F1-Score: 0.1756
#   mAP: 0.1663
# Epoch 3 Summary:
#   Loss: 0.2671
#   IoU: 0.5244
#   Precision: 0.1074
#   Recall: 1.2027
#   F1-Score: 0.1856
#   mAP: 0.1813
# Epoch 4 Summary:
#   Loss: 0.2611
#   IoU: 0.5470
#   Precision: 0.1185
#   Recall: 1.2347
#   F1-Score: 0.2027
#   mAP: 0.1997
# Epoch 5 Summary:
#   Loss: 0.2575
#   IoU: 0.5652
#   Precision: 0.1201
#   Recall: 1.2813
#   F1-Score: 0.2083
#   mAP: 0.2092
# Epoch 6 Summary:
#   Loss: 0.2531
#   IoU: 0.5817
#   Precision: 0.1243
#   Recall: 1.2926
#   F1-Score: 0.2148
#   mAP: 0.2183
# Epoch 7 Summary:
#   Loss: 0.2498
#   IoU: 0.5901
#   Precision: 0.1293
#   Recall: 1.3087
#   F1-Score: 0.2228
#   mAP: 0.2299
# Epoch 8 Summary:
#   Loss: 0.2444
#   IoU: 0.6045
#   Precision: 0.1304
#   Recall: 1.3270
#   F1-Score: 0.2262
#   mAP: 0.2369
# Epoch 9 Summary:
#   Loss: 0.2412
#   IoU: 0.6118
#   Precision: 0.1319
#   Recall: 1.3325
#   F1-Score: 0.2286
#   mAP: 0.2428
# Epoch 10 Summary:
#   Loss: 0.2368
#   IoU: 0.6201
#   Precision: 0.1361
#   Recall: 1.3347
#   F1-Score: 0.2352
#   mAP: 0.2527
# Epoch 11 Summary:
#   Loss: 0.2311
#   IoU: 0.6305
#   Precision: 0.1401
#   Recall: 1.3476
#   F1-Score: 0.2413
#   mAP: 0.2593
# Epoch 12 Summary:
#   Loss: 0.2267
#   IoU: 0.6392
#   Precision: 0.1401
#   Recall: 1.3424
#   F1-Score: 0.2412
#   mAP: 0.2659
# Epoch 13 Summary:
#   Loss: 0.2232
#   IoU: 0.6444
#   Precision: 0.1448
#   Recall: 1.3493
#   F1-Score: 0.2482
#   mAP: 0.2731
# Epoch 14 Summary:
#   Loss: 0.2194
#   IoU: 0.6479
#   Precision: 0.1474
#   Recall: 1.3548
#   F1-Score: 0.2522
#   mAP: 0.2803
# Epoch 15 Summary:
#   Loss: 0.2152
#   IoU: 0.6572
#   Precision: 0.1492
#   Recall: 1.3544
#   F1-Score: 0.2553
#   mAP: 0.2862

# %% [markdown]
# # TEST AND VALIDATION

# %%
# Validation function
def validate_model(model, data_loader, device):
    model.eval()
    total_loss = 0.0
    total_iou = 0.0
    total_precision = 0.0
    total_recall = 0.0
    
    with torch.no_grad():
        for images, targets in data_loader:
            images = list(img.to(device) for img in images)
            targets = [{k: v.to(device) for k, v in t.items()} for t in targets]
            
            loss_dict = model(images, targets)
            losses = sum(loss for loss in loss_dict.values())
            total_loss += losses.item()
            
            # Dummy values for IoU, Precision, Recall (replace with actual calculations)
            iou = torch.rand(1).item()
            precision = torch.rand(1).item()
            recall = torch.rand(1).item()
            
            total_iou += iou
            total_precision += precision
            total_recall += recall
    
    avg_loss = total_loss / len(data_loader)
    avg_iou = total_iou / len(data_loader)
    avg_precision = total_precision / len(data_loader)
    avg_recall = total_recall / len(data_loader)
    
    print(f"Validation: Avg Loss: {avg_loss:.4f}, IoU: {avg_iou:.4f}, Precision: {avg_precision:.4f}, Recall: {avg_recall:.4f}")

# Test function
def test_model(model, data_loader, device):
    print("Testing model...")
    validate_model(model, data_loader, device)

# %%
import matplotlib.pyplot as plt

# %%
# Plot training history
def plot_training_history(history):
    epochs = [epoch["epoch"] for epoch in history]
    losses = [epoch["loss"] for epoch in history]
    ious = [epoch["iou"] for epoch in history]
    precisions = [epoch["precision"] for epoch in history]
    recalls = [epoch["recall"] for epoch in history]
    
    plt.figure(figsize=(10, 5))
    plt.subplot(1, 2, 1)
    plt.plot(epochs, losses, label='Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title('Training Loss')
    plt.legend()
    
    plt.subplot(1, 2, 2)
    plt.plot(epochs, ious, label='IoU')
    plt.plot(epochs, precisions, label='Precision')
    plt.plot(epochs, recalls, label='Recall')
    plt.xlabel('Epoch')
    plt.ylabel('Metrics')
    plt.title('Object Detection Metrics')
    plt.legend()
    
    plt.tight_layout()
    plt.show()

# Display the training history graph
plot_training_history(history)
